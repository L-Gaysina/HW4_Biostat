# %% [markdown]
# <a href="https://colab.research.google.com/github/L-Gaysina/HW4_Biostat/blob/main/Cozyduke_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Сервис автоматического анализа текста двух документов и присвоения статуса соответсвия
# <hr>
#
#
# Над проектом работает:
# Команда **'COZYDUKE'.**
# 0. Кирсанов Вадим Вадимович
# 1. Казаченко Екатерина Александровна
# 2. Кириленков Кирилл Владимирович
# 3. Гайсина Лиана Ильдаровна
# 4. Федеряев Клим Александрович
# 5. Бадретдинова Рушания Ринатовна

# %%
# @title Дополнительные модули
# Установка дополнительных модулей
# %pip install python-docx
# %pip install POT
# %pip install torch

# Импорт библиотек и их модулей
import re
from io import BytesIO

import docx
import gensim.downloader as api
import numpy as np
import pandas as pd
import requests
import torch
from gensim.models import KeyedVectors
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import pairwise
from transformers import BertTokenizer, BertModel
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# Requirement already satisfied: python-docx in /usr/local/lib/python3.10/dist-packages (1.1.0)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-docx) (4.9.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from python-docx) (4.11.0)
# Requirement already satisfied: POT in /usr/local/lib/python3.10/dist-packages (0.9.3)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from POT) (1.25.2)
# Requirement already satisfied: scipy>=1.6 in /usr/local/lib/python3.10/dist-packages (from POT) (1.11.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.2.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %% [markdown]
# # 1. Подготовка данных
# * **Извлечение данных:** Данные были извлечены из файлов в формате DOCX с использованием библиотеки python-docx.
#
# * **Предобработка текста**: Произведена предобработка текстовых данных, включая удаление знаков пунктуации, приведение всех букв к нижнему регистру и удаление лишних пробелов. Эти шаги были выполнены с помощью регулярных выражений и методов обработки строк в Python.
#
# * **Создание датафреймов:** Составлено 2 датафрейма для каждого DOCX-документа, каждый из которых хранит весь текст из одного документа разбитого по абзацам

# %%
# Загрузка документов
# @title Для корректного выполнения кода вы можете заменить путь к файлу на свой в переменных docx_url и docx_url_req
def download_docx_from_url(url):
    response = requests.get(url)
    response.raise_for_status()
    return docx.Document(BytesIO(response.content))

# URL документа с характеристиками и требованиями
docx_url = 'https://docs.google.com/document/d/1iJPrBdchU1ZeXv-oW9cokJP1GN72WDGE/export?format=docx'
docx_url_req = 'https://docs.google.com/document/d/1TNUi3yUs_GFEhXOOTJE05ejvOXYdkQLe/export?format=docx'

# Загрузка документа Word
doc = download_docx_from_url(docx_url)
doc_req = download_docx_from_url(docx_url_req)

# %%
# @title Создание датафреймов

def parse_paragraphs_to_dataframe(doc):
    all_paragraphs = []
    current_header = "Без заголовка"  # Начальный заголовок для текста без явного разделения

    for para in doc.paragraphs:
        if para.text.strip():  # Проверка на непустой текст
            # Ищем пункты или заголовки, определяем по форматированию или содержимому
            if para.style.name.startswith('Heading') or (para.text.split()[0].replace('.', '').isdigit() and len(para.text.split()) > 1):
                current_header = para.text.split(maxsplit=1)[0] if para.text.split()[0].replace('.', '').isdigit() else para.text
            all_paragraphs.append((current_header, para.text))

    return pd.DataFrame(all_paragraphs, columns=['Заголовок', 'Текст параграфа'])

def add_section_numbers(df, text_column):
    # Компилируем регулярное выражение для поиска номеров пунктов
    pattern = re.compile(r'^(\d+(\.\d+)*)\s')

    # Функция для извлечения номера пункта из строки
    def extract_number(text):
        match = pattern.match(text)
        return match.group(1) if match else None

    # Применяем функцию к каждому элементу в столбце текста и создаем новую колонку
    df['Номер пункта'] = df[text_column].apply(extract_number)
    return df

# Парсим абзацы в DataFrame
df_all_text = parse_paragraphs_to_dataframe(doc)
df_all_text_req =  parse_paragraphs_to_dataframe(doc_req)

# Создаем колонку с номерами пунктов
df_all_text_req = add_section_numbers(df_all_text_req, 'Текст параграфа')
df_all_text = add_section_numbers(df_all_text, 'Текст параграфа')
df_all_text.head()
# Out:
#        Заголовок                                    Текст параграфа  \
# 0  Без заголовка                                         СОДЕРЖАНИЕ
# 1  Без заголовка  Настоящие технические условия распространяются...
# 2  Без заголовка  Агрегаты не предназначены для перекачивания кр...
# 3  Без заголовка  Допускается перекачивание жидкостей с температ...
# 4  Без заголовка  Агрегаты изготавливаются в климатическом испол...
#
#   Номер пункта
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None

# %%
# @title Обработка текста
def preprocess_text(df, text_column):
    df[text_column] = df[text_column].apply(lambda x: re.sub(r'[^\w\s]', '', x.lower()).replace('\n', ' ').strip())
    df[text_column] = df[text_column].apply(lambda x: re.sub(r'\s+', ' ', x))
    return df

def remove_short_requirements(df, column_name='текст требования'):
    """
    Удаляет строки из DataFrame, если количество слов в указанной колонке меньше 5.

    Параметры:
    df (pd.DataFrame): исходный DataFrame, из которого требуется удалить строки.
    column_name (str): имя колонки, в которой проверяется количество слов.

    Возвращает:
    pd.DataFrame: DataFrame после удаления строк.
    """
    # Фильтрация DataFrame: оставляем только те строки, где количество слов в column_name >= 5
    filtered_df = df[df[column_name].apply(lambda x: len(str(x).split()) >= 5)]

    return filtered_df

# Предварительная обработка текста в DataFrame
df_all_text = preprocess_text(df_all_text, 'Текст параграфа')
df_all_text_req = preprocess_text(df_all_text_req, 'Текст параграфа')

# Удаляем строки содержащие менее 5 слов
df_all_text_req = remove_short_requirements(df_all_text_req, 'Текст параграфа')
df_all_text = remove_short_requirements(df_all_text, 'Текст параграфа')

# Обновляем индекссацию после удаления
df_all_text_req = df_all_text_req.reset_index(drop=True)
df_all_text = df_all_text.reset_index(drop=True)

# Вывод результата
df_all_text.head(40)
# Out:
#                               Заголовок  \
# 0                         Без заголовка
# 1                         Без заголовка
# 2                         Без заголовка
# 3                         Без заголовка
# 4                         Без заголовка
# 5                         Без заголовка
# 6                         Без заголовка
# 7                         Без заголовка
# 8                         Без заголовка
# 9                         Без заголовка
# 10                        Без заголовка
# 11                        Без заголовка
# 12                        Без заголовка
# 13                        Без заголовка
# 14                        Без заголовка
# 15                        Без заголовка
# 16                        Без заголовка
# 17                        Без заголовка
# 18                        Без заголовка
# 19                        Без заголовка
# 20                        Без заголовка
# 21  Основные параметры и характеристики
# 22  Основные параметры и характеристики
# 23  Основные параметры и характеристики
# 24  Основные параметры и характеристики
# 25  Основные параметры и характеристики
# 26  Основные параметры и характеристики
# 27  Основные параметры и характеристики
# 28  Основные параметры и характеристики
# 29  Основные параметры и характеристики
# 30  Основные параметры и характеристики
# 31  Основные параметры и характеристики
# 32  Основные параметры и характеристики
# 33  Основные параметры и характеристики
# 34                Требования надежности
# 35                Требования надежности
# 36                Требования надежности
# 37                Требования надежности
# 38                Требования надежности
# 39           Конструктивные особенности
#
#                                       Текст параграфа Номер пункта
# 0   настоящие технические условия распространяются...         None
# 1   агрегаты не предназначены для перекачивания кр...         None
# 2   допускается перекачивание жидкостей с температ...         None
# 3   агрегаты изготавливаются в климатическом испол...         None
# 4            в условиях умеренного климата у2 45 40 с         None
# 5   в условиях умеренного и холодного климата ухл1...         None
# 6          в условиях холодного климата хл1хл2 6040 с         None
# 7   в условиях умереннохолодного и тропического мо...         None
# 8   допустимый диапазон температуры окружающей сре...         None
# 9   агрегаты могут поставляться в общепромышленном...         None
# 10  агрегаты во взрывозащищенном исполнении примен...         None
# 11  насосная часть агрегатов во взрывозащищенном и...         None
# 12  защита конструкционной безопасностью с по гост...         None
# 13     защита жидкостным погружением k по гост 314418         None
# 14  в случае если в составе агрегата во взрывозащи...         None
# 15  температурный класс агрегата зависит от максим...         None
# 16  по согласованию заказчика разработчика и завод...         None
# 17  варианты исполнения по материалу проточной час...         None
# 18  запуск насоса не полностью заполненного перека...         None
# 19  эксплуатация насоса с наличием паровой газовой...         None
# 20  насосная часть агрегатов выполняется на базе ц...         None
# 21  агрегаты должны соответствовать требованиям на...         None
# 22  показатели назначения по перекачиваемой жидкос...         None
# 23  показатели агрегатов по параметрам в номинальн...         None
# 24    максимально допустимые отклонения по параметрам         None
# 25                     для кавитационного запаса м 03         None
# 26  максимальное допускаемое давление на входе в н...         None
# 27  насосы должны сохранять свою работоспособность...         None
# 28  а синхронная частота вращения при максимальной...         None
# 29  б не менее 105 от номинальной частоты вращения...         None
# 30  насосы работающие совместно с регулируемым при...         None
# 31  мощность комплектуемого электродвигателя выбир...         None
# 32  допустимые значения средних уровней звука на р...         None
# 33  величина среднеквадратического значения виброс...         None
# 34  средний ресурс службы насоса до первого капита...         None
# 35  установленный срок службы 30 лет срок службы а...         None
# 36             средняя наработка на отказ 8 000 часов         None
# 37               среднее время восстановления 8 часов         None
# 38  указанные ресурсы и сроки службы действительны...         None
# 39  агрегаты имеют два варианта исполнения по расп...         None

# %%
# Вывод результата
df_all_text_req.head(40)
# Out:
#              Заголовок                                    Текст параграфа  \
# 0             Введение  использование настоящего стандарта в конкретны...
# 1             Введение  настоящий стандарт является модифицированным п...
# 2             Введение  дополнительные положения и требования а также ...
# 3             Введение  знак в начале параграфа или его раздела указыв...
# 4             Введение  из соображений удобства и в информационных цел...
# 5   Область применения  настоящий стандарт устанавливает требования к ...
# 6   Область применения  настоящий стандарт применяется к одноступенчат...
# 7   Область применения  п р и м е ч а н и е для распространения действ...
# 8   Область применения  опыт промышленной эксплуатации герметичных нас...
# 9   Область применения               давление на выходе 1900 кпа 275 psig
# 10  Область применения                  давление на входе 500 кпа 75 psig
# 11  Область применения                  температура перекачки 150 c 300 f
# 12  Область применения               номинальный общий напор 120 м 400 ft
# 13  Область применения                  диаметр рабочего колеса 330 мм 13
# 14  Область применения  для насосов с уплотнениями применяется стандарт 2
# 15  Нормативные ссылки  в настоящем стандарте использованы нормативные...
# 16  Нормативные ссылки  гост 12200391 система стандартов безопасности ...
# 17  Нормативные ссылки  гост 12206281 система стандартов безопасности ...
# 18  Нормативные ссылки  гост р 14812013 материалы металлические испыта...
# 19  Нормативные ссылки  гост 97788 отливки стальные общие технические ...
# 20  Нормативные ссылки  гост 332585 подшипники качения поля допусков и...
# 21  Нормативные ссылки  гост 61342007 исо 99061999 насосы динамические...
# 22  Нормативные ссылки  гост 751282 контроль неразрушающий соединения ...
# 23  Нормативные ссылки  гост р исо 850112014 подготовка стальной повер...
# 24  Нормативные ссылки  лакокрасочных материалов и относящихся к ним п...
# 25  Нормативные ссылки  гост 87242002 исо 26198 основные нормы взаимоз...
# 26  Нормативные ссылки  гост 945478 металлы метод испытания на ударный...
# 27  Нормативные ссылки  гост 1173793 ключи для винтов с внутренним шес...
# 28  Нормативные ссылки  гост 1478286 контроль неразрушающий соединения...
# 29  Нормативные ссылки  гост р исо 156092009 технические требования и ...
# 30  Нормативные ссылки  гост 160932004 исо 96511998 исо 96531998 основ...
# 31  Нормативные ссылки  взаимозаменяемости резьба метрическая допуски ...
# 32  Нормативные ссылки  гост 1698380 ключи гаечные комбинированные кон...
# 33  Нормативные ссылки  гост 1739272 направляющие и опорные детали пре...
# 34  Нормативные ссылки  гост 1844280 контроль неразрушающий капиллярны...
# 35  Нормативные ссылки  гост 1885594 исо 28189 подшипники качения дина...
# 36  Нормативные ссылки  гост исо 194012007 вибрация требования к качес...
# 37  Нормативные ссылки  гост 2110587 контроль неразрушающий магнитопор...
# 38  Нормативные ссылки  гост 2336078 основные нормы взаимозаменяемости...
# 39  Нормативные ссылки  гост 2406997 исо 311777 основные нормы взаимоз...
#
#    Номер пункта
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# 5          None
# 6          None
# 7          None
# 8          None
# 9          None
# 10         None
# 11         None
# 12         None
# 13         None
# 14         None
# 15         None
# 16         None
# 17         None
# 18         None
# 19         None
# 20         None
# 21         None
# 22         None
# 23         None
# 24         None
# 25         None
# 26         None
# 27         None
# 28         None
# 29         None
# 30         None
# 31         None
# 32         None
# 33         None
# 34         None
# 35         None
# 36         None
# 37         None
# 38         None
# 39         None

# %% [markdown]
# # 2. Векторизация текста и расчёт сходства
# * **Векторизация текста**: Используем TF-IDF векторизацию для преобразования текстов требований и параграфов в числовые векторы и подготовки данных к анализу сходства.
#
# * **Расчет косинусного сходства**: Вычисляем косинусное сходство между векторами параграфов и требований для определения степени соответствия между ними.

# %%
# @title Векторизация текста и расчёт косинусного сходства

# Подготовка текста: соберем все тексты параграфов в список
texts = df_all_text['Текст параграфа'].tolist()

# Подготовка списка текстов требований из предыдущей предобработки (словаря требований)
requirement_texts = df_all_text_req['Текст параграфа'].tolist()

# Объединение текстов требований и текстов параграфов для обучения одного TF-IDF векторизатора
combined_texts = texts + requirement_texts

# Создание и обучение TF-IDF векторизатора на объединенном корпусе
combined_tfidf_vectorizer = TfidfVectorizer()
combined_tfidf_matrix = combined_tfidf_vectorizer.fit_transform(combined_texts)

# Разделение матрицы TF-IDF на часть параграфов и часть требований
tfidf_paragraphs = combined_tfidf_matrix[:len(texts), :]
tfidf_requirements = combined_tfidf_matrix[len(texts):, :]

# Расчет косинусного сходства между параграфами и требованиями
cosine_similarities = cosine_similarity(tfidf_paragraphs, tfidf_requirements)

# Вывод формы матрицы сходств для проверки
cosine_similarities.shape
# Out:
# (179, 1676)

# %%
'''

# Инициализация токенизатора и модели
tokenizer = AutoTokenizer.from_pretrained('intfloat/multilingual-e5-large')
model = AutoModel.from_pretrained('intfloat/multilingual-e5-large')

# Функция для average pooling
def average_pool(last_hidden_states, attention_mask):
    last_hidden = last_hidden_states.masked_fill(~attention_mask[..., None].bool(), 0.0)
    return last_hidden.sum(dim=1) / attention_mask.sum(dim=1)[..., None]

# Объединение текстов параграфов и требований
combined_texts = texts + requirement_texts

# Токенизация текстов
inputs = tokenizer(combined_texts, return_tensors="pt", padding=True, truncation=True, max_length=512)

# Перенос данных на GPU, если доступно
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
inputs = {key: value.to(device) for key, value in inputs.items()}

# Получение эмбеддингов от модели
with torch.no_grad():
    outputs = model(**inputs)
    embeddings = average_pool(outputs.last_hidden_state, inputs['attention_mask'])

# Нормализация эмбеддингов
embeddings = F.normalize(embeddings, p=2, dim=1)

# Разделение эмбеддингов на параграфы и требования
paragraph_embeddings = embeddings[:len(texts)]
requirement_embeddings = embeddings[len(texts):]

# Расчет косинусного сходства
cosine_similarities = cosine_similarity(paragraph_embeddings.cpu().numpy(), requirement_embeddings.cpu().numpy())

# Вывод формы матрицы сходств для проверки
print(cosine_similarities.shape)
'''
# Out:
# '\n\n# Инициализация токенизатора и модели\ntokenizer = AutoTokenizer.from_pretrained(\'intfloat/multilingual-e5-large\')\nmodel = AutoModel.from_pretrained(\'intfloat/multilingual-e5-large\')\n\n# Функция для average pooling\ndef average_pool(last_hidden_states, attention_mask):\n    last_hidden = last_hidden_states.masked_fill(~attention_mask[..., None].bool(), 0.0)\n    return last_hidden.sum(dim=1) / attention_mask.sum(dim=1)[..., None]\n\n# Объединение текстов параграфов и требований\ncombined_texts = texts + requirement_texts\n\n# Токенизация текстов\ninputs = tokenizer(combined_texts, return_tensors="pt", padding=True, truncation=True, max_length=512)\n\n# Перенос данных на GPU, если доступно\ndevice = torch.device("cuda" if torch.cuda.is_available() else "cpu")\nmodel = model.to(device)\ninputs = {key: value.to(device) for key, value in inputs.items()}\n\n# Получение эмбеддингов от модели\nwith torch.no_grad():\n    outputs = model(**inputs)\n    embeddings = average_pool(outputs.last_hidden_state, inputs[\'attention_mask\'])\n\n# Нормализация эмбеддингов\nembeddings = F.normalize(embeddings, p=2, dim=1)\n\n# Разделение эмбеддингов на параграфы и требования\nparagraph_embeddings = embeddings[:len(texts)]\nrequirement_embeddings = embeddings[len(texts):]\n\n# Расчет косинусного сходства\ncosine_similarities = cosine_similarity(paragraph_embeddings.cpu().numpy(), requirement_embeddings.cpu().numpy())\n\n# Вывод формы матрицы сходств для проверки\nprint(cosine_similarities.shape)\n'

# %% [markdown]
# #3. Определение наилучших совпадений
# * **Анализ сходства:** Для каждого требования определяем абзац из второго файла с максимальным уровнем сходства и выявляем наиболее релевантные соответствия.
#
# * **Создание итогового отчета:** Результаты анализа собираем в датафрейме, который включает информацию о требованиях, соответствующих параграфов  и степени их сходства и выгружаем отчет в excel-файле.

# %%
# Инициализация пустого DataFrame для наилучших совпадений
best_match_df = pd.DataFrame(columns=['Пункт требования', 'Текст требования', 'Заголовок параграфа', 'Пункт параграфа', 'Текст параграфа', 'Сходство'])

# Сбор всех строк для добавления
rows_to_add = []
for req_index, req_row in df_all_text_req.iterrows():
    paragraph_index = np.argmax(cosine_similarities[:, req_index])
    max_similarity = cosine_similarities[paragraph_index, req_index]
    paragraph_data = df_all_text.loc[paragraph_index]
    paragraph_data_req = df_all_text_req.loc[paragraph_index]
    # Создание временного DataFrame для текущей строки
    temp_df = pd.DataFrame({
        'Заголовок требования': [req_row['Заголовок']],
        'Номер пункта требования': [req_row['Номер пункта']],
        'Текст требования': [req_row['Текст параграфа']],
        'Заголовок параграфа': [paragraph_data['Заголовок']],
        'Номер пункта параграфа': [paragraph_data['Номер пункта']],  # Предполагая, что 'Номер пункта' есть в df_all_text
        'Текст параграфа': [paragraph_data['Текст параграфа']],
        'Сходство': [max_similarity]
    })
    rows_to_add.append(temp_df)

# Добавление всех собранных строк в основной DataFrame
best_match_df = pd.concat(rows_to_add, ignore_index=True)

# Вывод первых нескольких строк для проверки
best_match_df.head(40)
# Out:
#    Заголовок требования Номер пункта требования  \
# 0              Введение                    None
# 1              Введение                    None
# 2              Введение                    None
# 3              Введение                    None
# 4              Введение                    None
# 5    Область применения                    None
# 6    Область применения                    None
# 7    Область применения                    None
# 8    Область применения                    None
# 9    Область применения                    None
# 10   Область применения                    None
# 11   Область применения                    None
# 12   Область применения                    None
# 13   Область применения                    None
# 14   Область применения                    None
# 15   Нормативные ссылки                    None
# 16   Нормативные ссылки                    None
# 17   Нормативные ссылки                    None
# 18   Нормативные ссылки                    None
# 19   Нормативные ссылки                    None
# 20   Нормативные ссылки                    None
# 21   Нормативные ссылки                    None
# 22   Нормативные ссылки                    None
# 23   Нормативные ссылки                    None
# 24   Нормативные ссылки                    None
# 25   Нормативные ссылки                    None
# 26   Нормативные ссылки                    None
# 27   Нормативные ссылки                    None
# 28   Нормативные ссылки                    None
# 29   Нормативные ссылки                    None
# 30   Нормативные ссылки                    None
# 31   Нормативные ссылки                    None
# 32   Нормативные ссылки                    None
# 33   Нормативные ссылки                    None
# 34   Нормативные ссылки                    None
# 35   Нормативные ссылки                    None
# 36   Нормативные ссылки                    None
# 37   Нормативные ссылки                    None
# 38   Нормативные ссылки                    None
# 39   Нормативные ссылки                    None
#
#                                      Текст требования  \
# 0   использование настоящего стандарта в конкретны...
# 1   настоящий стандарт является модифицированным п...
# 2   дополнительные положения и требования а также ...
# 3   знак в начале параграфа или его раздела указыв...
# 4   из соображений удобства и в информационных цел...
# 5   настоящий стандарт устанавливает требования к ...
# 6   настоящий стандарт применяется к одноступенчат...
# 7   п р и м е ч а н и е для распространения действ...
# 8   опыт промышленной эксплуатации герметичных нас...
# 9                давление на выходе 1900 кпа 275 psig
# 10                  давление на входе 500 кпа 75 psig
# 11                  температура перекачки 150 c 300 f
# 12               номинальный общий напор 120 м 400 ft
# 13                  диаметр рабочего колеса 330 мм 13
# 14  для насосов с уплотнениями применяется стандарт 2
# 15  в настоящем стандарте использованы нормативные...
# 16  гост 12200391 система стандартов безопасности ...
# 17  гост 12206281 система стандартов безопасности ...
# 18  гост р 14812013 материалы металлические испыта...
# 19  гост 97788 отливки стальные общие технические ...
# 20  гост 332585 подшипники качения поля допусков и...
# 21  гост 61342007 исо 99061999 насосы динамические...
# 22  гост 751282 контроль неразрушающий соединения ...
# 23  гост р исо 850112014 подготовка стальной повер...
# 24  лакокрасочных материалов и относящихся к ним п...
# 25  гост 87242002 исо 26198 основные нормы взаимоз...
# 26  гост 945478 металлы метод испытания на ударный...
# 27  гост 1173793 ключи для винтов с внутренним шес...
# 28  гост 1478286 контроль неразрушающий соединения...
# 29  гост р исо 156092009 технические требования и ...
# 30  гост 160932004 исо 96511998 исо 96531998 основ...
# 31  взаимозаменяемости резьба метрическая допуски ...
# 32  гост 1698380 ключи гаечные комбинированные кон...
# 33  гост 1739272 направляющие и опорные детали пре...
# 34  гост 1844280 контроль неразрушающий капиллярны...
# 35  гост 1885594 исо 28189 подшипники качения дина...
# 36  гост исо 194012007 вибрация требования к качес...
# 37  гост 2110587 контроль неразрушающий магнитопор...
# 38  гост 2336078 основные нормы взаимозаменяемости...
# 39  гост 2406997 исо 311777 основные нормы взаимоз...
#
#                                   Заголовок параграфа Номер пункта параграфа  \
# 0                               Требования надежности                   None
# 1                                       Без заголовка                   None
# 2                                          Маркировка                   None
# 3                                     Методы контроля                   None
# 4                                     Методы контроля                   None
# 5                                       Без заголовка                   None
# 6                                                7.14                   None
# 7                                                7.14                   None
# 8                             Требования безопасности                   None
# 9                 Основные параметры и характеристики                   None
# 10                                                7.5                   None
# 11                                      Без заголовка                   None
# 12                                      Без заголовка                   None
# 13                                      Без заголовка                   None
# 14                         Конструктивные особенности                   None
# 15  Перечень документов, на которые даны ссылки в ...                   None
# 16                                               7.16                   None
# 17                                               7.16                   None
# 18  Требования к материалам, покупным изделиям и и...                   None
# 19                       Транспортирование и хранение                   None
# 20  Требования к материалам, покупным изделиям и и...                   None
# 21  Требования к материалам, покупным изделиям и и...                   None
# 22                                    Правила приемки                   None
# 23  Требования к материалам, покупным изделиям и и...                   None
# 24  Требования к материалам, покупным изделиям и и...                   None
# 25  Требования к материалам, покупным изделиям и и...                   None
# 26                                    Методы контроля                   None
# 27                       Транспортирование и хранение                   None
# 28                                    Правила приемки                   None
# 29                                               7.16                   None
# 30                                    Правила приемки                   None
# 31  Требования к материалам, покупным изделиям и и...                   None
# 32   Габаритные и присоединительные размеры агрегатов                   None
# 33                                               7.16                   None
# 34                                               7.16                   None
# 35                         Конструктивные особенности                   None
# 36                                               7.16                   None
# 37                                    Правила приемки                   None
# 38   Габаритные и присоединительные размеры агрегатов                   None
# 39                                    Правила приемки                   None
#
#                                       Текст параграфа  Сходство
# 0   указанные ресурсы и сроки службы действительны...  0.080409
# 1   по согласованию заказчика разработчика и завод...  0.116601
# 2   табличка агрегатов электронасосных устанавлива...  0.047446
# 3   материалы проверка сертификатов или проведение...  0.090388
# 4   в процессе изготовления и приемки деталей и сб...  0.179324
# 5   эксплуатация насоса с наличием паровой газовой...  0.076962
# 6   контроль температуры герметизирующего экрана д...  0.078046
# 7   714 для предотвращения отказов и аварий насосы...  0.088502
# 8   при эксплуатации агрегата запрещается устранят...  0.107133
# 9   максимальное допускаемое давление на входе в н...  0.078796
# 10  75 периодичность технического обслуживания сог...  0.175826
# 11  настоящие технические условия распространяются...  0.000000
# 12  настоящие технические условия распространяются...  0.000000
# 13  допускается перекачивание жидкостей с температ...  0.190645
# 14  агрегаты с торцовыми уплотнениями по требовани...  0.161805
# 15  перечень документов на которые даны ссылки в н...  0.201599
# 16  716 требования безопасности агрегатов должны с...  0.307060
# 17  716 требования безопасности агрегатов должны с...  0.181638
# 18  метрическая резьба по гост 9150 и гост 24705 п...  0.116193
# 19                   условия хранения 6 по гост 15150  0.193560
# 20  метрическая резьба по гост 9150 и гост 24705 п...  0.185033
# 21  метрическая резьба по гост 9150 и гост 24705 п...  0.174795
# 22                 безопасность гост 31839 гост 31840  0.124688
# 23  подготовка металлических поверхностей перед ок...  0.126665
# 24  материалы прокладок и уплотнений а также матер...  0.080539
# 25  метрическая резьба по гост 9150 и гост 24705 п...  0.182641
# 26  испытания на надежность проводятся при подконт...  0.101617
# 27                   условия хранения 6 по гост 15150  0.169689
# 28                 безопасность гост 31839 гост 31840  0.114407
# 29  716 требования безопасности агрегатов должны с...  0.140127
# 30                 безопасность гост 31839 гост 31840  0.101439
# 31  метрическая резьба по гост 9150 и гост 24705 п...  0.166981
# 32   габаритные и присоединительные размеры агрегатов  0.120249
# 33  716 требования безопасности агрегатов должны с...  0.124562
# 34  716 требования безопасности агрегатов должны с...  0.153712
# 35  в качестве опор ротора используются подшипники...  0.115221
# 36  716 требования безопасности агрегатов должны с...  0.140183
# 37                 безопасность гост 31839 гост 31840  0.126561
# 38   габаритные и присоединительные размеры агрегатов  0.082249
# 39                 безопасность гост 31839 гост 31840  0.118413

# %%
# Функция для категоризации сходства
def categorize_similarity(similarity):
    if similarity >= 0.1:
        return "Соответствует"
    elif similarity >= 0.07:
        return "Частично соответствует"
    else:
        return "Не соответствует"

# Применение функции к колонке 'Сходство'
best_match_df['Степень соответствия'] = best_match_df['Сходство'].apply(categorize_similarity)
best_match_df
# Out:
#                               Заголовок требования Номер пункта требования  \
# 0                                         Введение                    None
# 1                                         Введение                    None
# 2                                         Введение                    None
# 3                                         Введение                    None
# 4                                         Введение                    None
# ...                                            ...                     ...
# 1671                                  Приложение S                    None
# 1672                                  Библиография                    None
# 1673                                  Библиография                    None
# 1674  РАЗДЕЛ 2. Иностранные стандарты на материалы                    None
# 1675  РАЗДЕЛ 2. Иностранные стандарты на материалы                    None
#
#                                        Текст требования  \
# 0     использование настоящего стандарта в конкретны...
# 1     настоящий стандарт является модифицированным п...
# 2     дополнительные положения и требования а также ...
# 3     знак в начале параграфа или его раздела указыв...
# 4     из соображений удобства и в информационных цел...
# ...                                                 ...
# 1671  сведения о соответствии межгосударственных ста...
# 1672  раздел 1 иностранные стандарты и нормативные д...
# 1673  американская ассоциация инженеровмехаников рук...
# 1674        раздел 2 иностранные стандарты на материалы
# 1675           в алфавитном порядке по номеру стандарта
#
#                                     Заголовок параграфа  \
# 0                                 Требования надежности
# 1                                         Без заголовка
# 2                                            Маркировка
# 3                                       Методы контроля
# 4                                       Методы контроля
# ...                                                 ...
# 1671  Требования к материалам, покупным изделиям и и...
# 1672  Требования к материалам, покупным изделиям и и...
# 1673                                      Комплектность
# 1674                                    Правила приемки
# 1675                                         Маркировка
#
#      Номер пункта параграфа  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ...                     ...
# 1671                   None
# 1672                   None
# 1673                   None
# 1674                   None
# 1675                   None
#
#                                         Текст параграфа  Сходство  \
# 0     указанные ресурсы и сроки службы действительны...  0.080409
# 1     по согласованию заказчика разработчика и завод...  0.116601
# 2     табличка агрегатов электронасосных устанавлива...  0.047446
# 3     материалы проверка сертификатов или проведение...  0.090388
# 4     в процессе изготовления и приемки деталей и сб...  0.179324
# ...                                                 ...       ...
# 1671  все материалы поступающие в производство для и...  0.056442
# 1672  все материалы поступающие в производство для и...  0.102429
# 1673   паспорт и руководство по эксплуатации 1 комплект  0.197749
# 1674  материалы покупные и комплектующие изделия дол...  0.089101
# 1675  табличка агрегатов электронасосных устанавлива...  0.081980
#
#         Степень соответствия
# 0     Частично соответствует
# 1              Соответствует
# 2           Не соответствует
# 3     Частично соответствует
# 4              Соответствует
# ...                      ...
# 1671        Не соответствует
# 1672           Соответствует
# 1673           Соответствует
# 1674  Частично соответствует
# 1675  Частично соответствует
#
# [1676 rows x 8 columns]

# %%
# @title Скачиваем итоговый файл
# Путь для сохранения файла Excel
file_path = 'output.xlsx'

# Сохранение DataFrame в файл Excel
best_match_df.to_excel(file_path, index=False, engine='openpyxl')

# %% [markdown]
# #4. Изучение альтернативных способов определения сходства
#
# * **Использование модели BERT**: Для начала, был загружен предобученный токенизатор и модель BERT (bert-base-uncased) из библиотеки Hugging Face. Эта модель является одной из базовых версий BERT, предназначенной для работы с текстами.
#
# * **Работа с текстами**
# Списки текстов из параграфов и требований были подготовлены для обработки. Тексты были извлечены из датафрейма best_match_df, который содержал информацию о наилучшем соответствии между параграфами и требованиями.Для каждого списка текстов были получены соответствующие эмбеддинги. С использованием функции косинусного сходства было рассчитано соответствие между параграфами и требованиями.
#
# * Однако полученные результаты оказались чересчур оптимистичными и  малоинформативными.

# %%
# Загрузка предобученного токенизатора и модели BERT
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased', return_dict=True)

def get_bert_embeddings(texts):
    """Функция для получения BERT эмбеддингов."""
    encoded_input = tokenizer(texts, padding=True, truncation=True, return_tensors='pt', max_length=512)
    with torch.no_grad():
        outputs = model(**encoded_input)
    # Используем [CLS] токен для представления всего текста
    embeddings = outputs.last_hidden_state[:, 0, :].numpy()
    return embeddings

# Подготовка текстов
texts = best_match_df['Текст параграфа'].tolist()
requirements = best_match_df['Текст требования'].tolist()

# Получение эмбеддингов
paragraph_embeddings = get_bert_embeddings(texts)
requirement_embeddings = get_bert_embeddings(requirements)

# Расчет косинусного сходства
cosine_sim = cosine_similarity(paragraph_embeddings, requirement_embeddings)

# Сохранение сходства в DataFrame
for idx in range(len(best_match_df)):
    best_match_df.at[idx, 'Сходство BERT'] = cosine_sim[idx, idx]  # диагональные элементы, если порядок соответствует

# Вывод первых строк DataFrame для проверки
best_match_df.head(20)
# Out:
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %% [markdown]
# * **Загрузка модели Word2Vec:** Использовалась предобученная модель Word2Vec ('word2vec-google-news-300') из коллекции Google News, загруженная через API gensim.
#
# * **Подготовка модели:** После загрузки убедились, что модель доступна как объект KeyedVectors для использования функции wmdistance, которая позволяет вычислять расстояние по методу Word Mover's Distance (WMD) между двумя текстами.
#
# * **Функция расчёта WMD:** Реализована функция calculate_wmd, которая принимает два текста, преобразует их в нижний регистр, разбивает на слова и вычисляет WMD. Этот метод основан на минимальном расстоянии, необходимом для преобразования всех слов в одном документе в слова другого документа, учитывая их семантическую близость.
#
# * **Применение WMD к данным:** Для каждой пары текстов (требования и соответствующий параграф) в DataFrame best_match_df было вычислено WMD, что позволило оценить их семантическую близость. Результаты сохранены в столбец WMD_Similarity данного DataFrame.

# %%
# Загрузка предобученной модели Word2Vec
model = api.load('word2vec-google-news-300')

# Обеспечение, что модель полностью загружена как KeyedVectors для доступа к функции wmdistance
if not isinstance(model, KeyedVectors):
    model = model.wv

# Функция для вычисления WMD
def calculate_wmd(text1, text2, model):
    text1 = text1.lower().split()
    text2 = text2.lower().split()
    return model.wmdistance(text1, text2)

# Вычисление WMD для каждой пары и добавление в DataFrame
best_match_df['WMD_Similarity'] = best_match_df.apply(lambda row: calculate_wmd(row['Текст требования'], row['Текст параграфа'], model), axis=1)

# Вывод первых нескольких строк для проверки
best_match_df.head(16)

# %% [markdown]
# #Интерпретация значений WMD
# * Большие значения WMD: Высокое значение WMD указывает на то, что тексты сильно различаются с семантической точки зрения. Слова в этих текстах находятся далеко друг от друга в векторном пространстве, что свидетельствует о большой разнице в содержании или контексте.
#
# * Маленькие значения WMD: Низкое значение WMD означает, что тексты семантически близки. Слова из одного текста находятся близко к словам другого текста в векторном пространстве, что указывает на схожесть или релевантность тем или идей между текстами.
#
# * Нулевое значение WMD: Если WMD равно нулю, это означает, что тексты идентичны с точки зрения используемых слов и их векторных представлений, хотя на практике такое встречается редко, если только тексты не являются полными дубликатами.
